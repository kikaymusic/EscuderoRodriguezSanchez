# %% [markdown]
# <a href="https://colab.research.google.com/github/kikaymusic/EscuderoRodriguezSanchez/blob/main/Entornos_Complejos/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introducción al Problema
#
# En este segundo capítulo de la práctica vamos a estudiar el uso de algoritmos para el aprendizaje por refuerzo en entornos complejos. Los primeros algoritmos con los que vamos a probar son los métodos tabulares, compuestos por Monte Carlo, SARSA y Q-Learning. Para esta parte, vamos a comparar por un lado Monte Carlo On-Policy y Off-Policy, y por otro SARSA y Q-Learning. Este notebook sirve como punto para navegar a los notebooks donde realizaremos los estudios de los algoritmos.

# %% [markdown]
# ## Navegación entre Estudios
#
# Haz clic en los siguientes enlaces para abrir los cuadernos de análisis específicos en Google Colab:
#
# * ### [1. Metodos tabulares](https://colab.research.google.com/github/kikaymusic/EscuderoRodriguezSanchez/blob/main/Entornos_Complejos/notebook_metodos_tabulares.ipynb)
#     * Análisis y comparación de los métodos tabulares, compuestos por Monte Carlo (On-Policy y Off-Policy), SARSA y Q-Learning.
# * ### [2. Control con Aproximaciones](https://colab.research.google.com/github/kikaymusic/EscuderoRodriguezSanchez/blob/main/Entornos_Complejos/notebook_control_aproximaciones.ipynb)
#     * Análisis y comparación entre los algoritmos de control con aproximaciones, SARSA semi-gradiente y Deep Q-Learning.
